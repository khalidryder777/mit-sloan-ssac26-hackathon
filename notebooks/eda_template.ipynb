# %% [markdown]
# # MIT Sloan SSAC 2026 Hackathon — EDA Template
#
# This notebook provides a starting point for exploratory data analysis (EDA).
# Data will be placed in the `data/` directory on Thursday AM.

# %% [markdown]
# ## 1. Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from scipy import stats

sns.set_theme(style='whitegrid')
# %matplotlib inline

# %% [markdown]
# ## 2. Load Data

# %%
# Update this path once data is available in data/
DATA_PATH = '../data/'

# Example: df = pd.read_csv(DATA_PATH + 'dataset.csv')
# df = pd.read_csv(DATA_PATH + 'dataset.csv')
# df.head()

# %% [markdown]
# ## 3. Automated Profiling
#
# Uncomment one of the profiling options below after loading the data.

# %%
# --- Option A: ydata-profiling ---
# from ydata_profiling import ProfileReport
# profile = ProfileReport(df, title='Dataset Profile', explorative=True)
# profile.to_notebook_iframe()

# --- Option B: sweetviz ---
# import sweetviz as sv
# report = sv.analyze(df)
# report.show_notebook()

# %% [markdown]
# ## 4. Basic Dataset Overview

# %%
# df.shape
# df.dtypes
# df.describe(include='all')
# df.isnull().sum()

# %% [markdown]
# ## 5. Univariate Analysis

# %%
# Numeric distributions
# num_cols = df.select_dtypes(include=np.number).columns.tolist()
# df[num_cols].hist(bins=30, figsize=(16, 10))
# plt.tight_layout()
# plt.show()

# %%
# Categorical value counts
# cat_cols = df.select_dtypes(include='object').columns.tolist()
# for col in cat_cols:
#     print(df[col].value_counts())
#     print()

# %% [markdown]
# ## 6. Bivariate / Correlation Analysis

# %%
# Correlation heatmap
# plt.figure(figsize=(12, 8))
# sns.heatmap(df[num_cols].corr(), annot=True, fmt='.2f', cmap='coolwarm')
# plt.title('Correlation Matrix')
# plt.show()

# %% [markdown]
# ## 7. Interactive Exploration with Plotly

# %%
# Example scatter plot — replace columns as needed
# fig = px.scatter(df, x=num_cols[0], y=num_cols[1], color=cat_cols[0] if cat_cols else None)
# fig.show()

# %% [markdown]
# ## 8. Text Analysis (if applicable)

# %%
# from textblob import TextBlob
# text_col = 'your_text_column'
# df['sentiment'] = df[text_col].astype(str).apply(lambda t: TextBlob(t).sentiment.polarity)
# df['sentiment'].hist(bins=30)
# plt.title('Sentiment Distribution')
# plt.show()

# %% [markdown]
# ## 9. Next Steps / Notes
#
# - [ ] Identify key features for clustering
# - [ ] Handle missing values / outliers
# - [ ] Feature engineering
# - [ ] Run `scripts/clustering_pipeline.py`
